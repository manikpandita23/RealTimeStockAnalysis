# %%
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  ... Sr_no
# 0                          Corporate Bonds  ...     1
# 1                          Corporate Bonds  ...     2
# 2                          Corporate Bonds  ...     3
# 3                          Corporate Bonds  ...     4
# 4                          Corporate Bonds  ...     5
# ..                                     ...  ...   ...
# 16  Securities Lending & Borrowing Schemes  ...    17
# 17  Securities Lending & Borrowing Schemes  ...    18
# 18  Securities Lending & Borrowing Schemes  ...    19
# 19  Securities Lending & Borrowing Schemes  ...    20
# 20  Securities Lending & Borrowing Schemes  ...    21
#
# [247 rows x 5 columns]
